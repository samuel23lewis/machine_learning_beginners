# %% [markdown]
# Normal data distribution or Gaussian data distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

#5 is the mean value and 1 is the standard deviation and 100000 to draw 100 bars
x=np.random.normal(5,1,100000)
plt.hist(x,100)
plt.show()
