# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.normal(0,10,5)
y=np.random.normal(0,10,5)
print(x)
print(y)
plt.scatter(x,y)
plt.show()
# Out:
# [-0.63441847  5.44638424  0.57594299 12.70894062 -2.4024012 ]
# [ -4.43153692  -7.60629318   1.29322326 -27.21475238  -7.73146979]
